# %%
# Import libraries
import random

from aitextgen import aitextgen

import tracery
from tracery.modifiers import base_english

import spacy
nlp = spacy.load("en_core_web_sm")

# %%
rules = {
    'question': ['What is #noun#?',
                 'Why is #noun# #adjective#?',
                 'What is #adjective# #noun#?',
                 'What if #noun# is also #noun#?',
                 'What if #noun# is #adjective#?',
                 'What will happen if #noun# is also #noun#?',
                 'What will happen if #noun# is #adjective#?',
                 'Why is it #adjective# to be #adjective#?',
                 'Why is it #adjective# to be #noun#?',
                 'What is the best way to be #adjective#?',
                 'What is the best way to be #noun#?',
                 'What is the worst way to be #adjective#?',
                 'What is the worst way to be #noun#?',
                 'Can #noun# be too #adjective#?'],
    'noun': ['philosophy',
             'a philosopher',
             'literature',
             'debate',
             'an author',
             'a poet',
             'humanity', 
             'identity',
             'faith', 
             'peace',
             'success',
             'leadership',
             'a lady',
             'a gentleman',
             'a woman',
             'a man',
             'a leader',
             'a family',
             'a nation',
             'a king',
             'a queen',
             'a monarch',
             'an oligarch',
             'a kingdom',
             'a monarchy', 
             'a democracy',
             'an oligarchy',
             'good',
             'evil',
             'fame',
             'infamy',
             'a criminal',
             'a gangster',
             'legalism',
             'a technocracy',
             'a corporation',
             'a government',
             'a governor',
             'a judge',
             'a court',
             'a legislator',
             'tyranny',
             'a tyrant',
             'an actor',
             'an actress',
             'a child',
             'a soldier',
             'a military',
             'a general',
             'a lover',
             'an ideal',
             'unity',
             'division',
             'mercy',
             'justice',
             'revenge',
             'punishment',
             'vengeance',
             'a weapon',
             'a warrior',
             'technology',
             'a slave',
             'a genius',
             'a war',
             'a struggle',
             'independence',
             'dependence',
             'addiction',
             'hope',
             'love',
             'joy',
             'terror',
             'fear',
             'sovereignty',
             'a sovereign',
             'a conqueror',
             'bravery',
             'a colony',
             'a husband',
             'a wife',
             'a father',
             'a mother',
             'law',
             'history',
             'the past',
             'the present',
             'the future',
             'a gift',
             'generosity',
             'honor',
             'a knight',
             'a servant',
             'royalty',
             'tradition',
             'a commoner',
             'health',
             'wealth',
             'treasure',
             'truth',
             'lie',
             'honesty',
             'modesty',
             'responsibility',
             'wisdom',
             'knowledge',
             'sportsmanship',
             'time',
             'malice',
             'the lesson',
             'a monster',
             'a beast'],
    'adjective': ['important', 
                  'unimportant',
                  'relevant',
                  'irrelevant',
                  'big',
                  'small',
                  'inflammatory', 
                  'necessary',
                  'good',
                  'evil',
                  'terrible',
                  'famous',
                  'infamous',
                  'criminal',
                  'legal',
                  'divine',
                  'moral',
                  'immoral',
                  'strict',
                  'lazy',
                  'ideal',
                  'romantic',
                  'objective',
                  'united',
                  'divided',
                  'merciful',
                  'kind',
                  'sensible',
                  'insane',
                  'genius',
                  'mad',
                  'maddenning',
                  'infuriating',
                  'dangerous',
                  'independent',
                  'dependent',
                  'lonely',
                  'joyful',
                  'happy',
                  'sad',
                  'law-abiding',
                  'poetic',
                  'drunk',
                  'crazy',
                  'upset',
                  'fallen',
                  'unjust',
                  'common',
                  'rare',
                  'healthy',
                  'treasured',
                  'honest',
                  'dishonest',
                  'prudent',
                  'imprudent',
                  'wise', 
                  'unwise',
                  'pure',
                  'late',
                  'enough',
                  'dead',
                  'mighty',
                  'monstrous']
}

# %%
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)

# %%
ai = aitextgen(model_folder='trained_model_philosophy',
               to_gpu=True)

# %%
text = ''

# %%
my_prompt = grammar.flatten('What is drunk philosophy?')
word_count = 0
text = '# ' + my_prompt

# %%
with open('story_philosophy_1.txt', 'rb') as file:
    text = str(file.read())
#my_prompt = grammar.flatten('#question#')
my_prompt = 'What Will Happen If A Government Is Also Modesty?'
word_count = len(text.split(' '))

# %%
while word_count < 60000:
    try:
        print('Written', word_count, 'words...')
        new_text = ai.generate_one(prompt=my_prompt,
                                   max_length=2048,
                                   temperature=1.25,
                                   top_p=0.8,
                                   num_beams=4,
                                   repetition_penalty=5.0
                                   )
        doc = nlp(new_text)
        assert doc.has_annotation("SENT_START")
        sents = [sent for sent in doc.sents]
        remove = str(sents[-1])
        if random.uniform(0, 1) < 0.25:
            try:
                my_prompt = str(sents[-2])
                text += '\n\n' + new_text.replace(remove, '').replace(my_prompt, '')
            except Exception as e:
                print(e)
                text += '\n\n' + new_text.replace(remove, '')
                my_prompt = grammar.flatten('#question#')
                text += '\n\n# ' + my_prompt.title()
        else:
            text += '\n\n' + new_text.replace(remove, '')
            my_prompt = grammar.flatten('#question#')
            text += '\n\n# ' + my_prompt.title()
        with open('story_philosophy_1.txt', 'wb') as f:
            f.write(bytes(text, 'utf-8'))
        word_count = len(text.split(' '))
    except Exception as e:
        print(e)
        pass
# Out:
# Written 42311 words...
# Written 42804 words...
# Written 42830 words...
# Written 43026 words...
# Written 43337 words...
# Written 44109 words...
# Written 44296 words...
# Written 44553 words...
# Written 44980 words...
# Written 45172 words...
# Written 45289 words...
# Written 45487 words...
# Written 46570 words...
# Written 47453 words...
# Written 47718 words...
# Written 48578 words...
# Written 48729 words...
# Written 48896 words...
# Written 49061 words...
# Written 49558 words...
# Written 49968 words...
# Written 50159 words...
# Written 50303 words...
# Written 50674 words...
# Written 50819 words...
# Written 51037 words...
# Written 51937 words...
# Written 52370 words...
# Written 52597 words...
# Written 52829 words...
# Written 53168 words...
# Written 53258 words...
# Written 53561 words...
# Written 53674 words...
# list index out of range
# Written 53682 words...
# Written 53962 words...
# Written 54308 words...
# Written 54461 words...
# Written 54608 words...
# Written 54616 words...
# Written 54806 words...
# Written 54950 words...
# Written 56356 words...
# Written 56552 words...
# Written 57003 words...
# Written 57566 words...
# Written 58701 words...
# Written 59086 words...
# Written 59637 words...
